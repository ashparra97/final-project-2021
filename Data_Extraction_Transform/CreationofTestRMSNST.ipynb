# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 994 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 37.7 MB/s
# ...
#      |████████████████████████████████| 15.4 MB 34 kB/s
# ...

# %%
#importing libraries
import geopandas as gpd
import pandas as pd

# %%
df = pd.read_csv('all_month(3).csv', error_bad_lines=False)
df
# Out:
# b'Skipping line 5501: expected 22 fields, saw 23\n'
#                            time          latitude  ... locationSource  magSource
# 0      2021-08-19T02:53:29.951Z           38.5412  ...             nn         nn
# 1      2021-08-19T02:49:35.880Z        35.8966667  ...             ci         ci
# 2      2021-08-19T02:49:14.046Z           59.8651  ...             ak         ak
# 3      2021-08-19T02:46:16.400Z         38.784668  ...             nc         nc
# 4      2021-08-19T02:42:46.880Z           56.6574  ...             ak         ak
# ...                         ...               ...  ...            ...        ...
# 17731  2021-07-20T03:11:29.020Z  42.0571666666667  ...             uw         uw
# 17732  2021-07-20T03:08:10.671Z          -12.2261  ...             us         us
# 17733  2021-07-20T03:08:03.959Z           59.1608  ...             ak         ak
# 17734  2021-07-20T03:07:04.750Z           43.1555  ...             uw         uw
# ...

# %%
clean_df = df.drop(['dmin', 'magError', 'depthError', 'horizontalError', 'magSource', 'status'], axis=1)
clean_df
# Out:
#                            time          latitude  ... magNst  locationSource
# 0      2021-08-19T02:53:29.951Z           38.5412  ...    4.0              nn
# 1      2021-08-19T02:49:35.880Z        35.8966667  ...    8.0              ci
# 2      2021-08-19T02:49:14.046Z           59.8651  ...    NaN              ak
# 3      2021-08-19T02:46:16.400Z         38.784668  ...    4.0              nc
# 4      2021-08-19T02:42:46.880Z           56.6574  ...    NaN              ak
# ...                         ...               ...  ...    ...             ...
# 17731  2021-07-20T03:11:29.020Z  42.0571666666667  ...    2.0              uw
# 17732  2021-07-20T03:08:10.671Z          -12.2261  ...   27.0              us
# 17733  2021-07-20T03:08:03.959Z           59.1608  ...    NaN              ak
# 17734  2021-07-20T03:07:04.750Z           43.1555  ...    3.0              uw
# 17735  2021-07-20T03:05:26.378Z            -35.35  ...   11.0              us
#
# [17736 rows x 16 columns]

# %%
Dropped_df = clean_df.dropna()
Dropped_df
# Out:
#                            time          latitude  ... magNst  locationSource
# 0      2021-08-19T02:53:29.951Z           38.5412  ...    4.0              nn
# 1      2021-08-19T02:49:35.880Z        35.8966667  ...    8.0              ci
# 3      2021-08-19T02:46:16.400Z         38.784668  ...    4.0              nc
# 5      2021-08-19T02:39:51.510Z        34.0321667  ...   27.0              ci
# 6      2021-08-19T02:37:55.960Z        35.4566667  ...   26.0              ci
# ...                         ...               ...  ...    ...             ...
# 17727  2021-07-20T03:20:06.360Z        40.7223333  ...    5.0              uu
# 17728  2021-07-20T03:19:03.610Z        35.4806667  ...    2.0              ci
# 17729  2021-07-20T03:16:23.250Z           33.6985  ...   10.0              ci
# 17731  2021-07-20T03:11:29.020Z  42.0571666666667  ...    2.0              uw
# 17734  2021-07-20T03:07:04.750Z           43.1555  ...    3.0              uw
#
# [12889 rows x 16 columns]

# %%
Dropped_df.to_csv("TestwithRMSandNST.csv")
