# %%
#from https://stackoverflow.com/questions/54300263/connect-to-aws-rds-postgres-database-with-python
import psycopg2


from sqlalchemy import create_engine

engine = create_engine('postgresql+psycopg2://root:-----@host:port/postgres')

# %%
import pandas as pd

df = pd.read_csv(r'/Users/rosaicelaroman/Desktop/Data_BootCamp/final-project-2021/Data_Extraction_Transform/dropped_NaN_month_earthquake.csv', index_col=0)
df.head(5)
# Out:
#            id  tsunami  felt                      time   latitude   longitude  \
# 0  ci40014592        0   1.0  2021-08-18T21:57:15.190Z  33.070500 -115.946667
# 1  ci40014576        0   7.0  2021-08-18T21:50:22.940Z  33.074833 -115.967500
# 2  us6000f843        0   0.0  2021-08-18T21:49:57.136Z -59.709300  -26.369300
# 3  hv72653902        0   1.0  2021-08-18T21:46:14.940Z  19.216833 -155.411667
# 4  ci40014560        0  40.0  2021-08-18T21:45:14.590Z  33.073333 -115.959833
#
#        depth   mag magType    gap net                   updated  \
# 0   7.370000  1.57      ml   37.0  ci  2021-08-18T22:57:59.267Z
# 1   3.840000  3.84      mw   29.0  ci  2021-08-18T23:52:47.436Z
# 2  38.080000  5.90     mww   46.0  us  2021-08-18T23:53:58.675Z
# 3  31.360001  2.13      ml  143.0  hv  2021-08-18T21:58:16.291Z
# 4   7.070000  3.98      mw   21.0  ci  2021-08-19T02:58:25.719Z
#
#                             place        type locationSource
# ...

# %%
df.to_sql('earthquake_felt', engine, if_exists='replace', index = False)

# %%
engine.dispose()
